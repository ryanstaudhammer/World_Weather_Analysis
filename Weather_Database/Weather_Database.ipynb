# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API keys.
from config import weather_api_key
from config import g_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Look at JSON format.
portland_url = url + "&q=" + "Portland"
city_weather = requests.get(portland_url)
city_weather.json()
# Out:
# {'coord': {'lon': -122.6762, 'lat': 45.5234},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 63.05,
#   'feels_like': 61.54,
#   'temp_min': 59.52,
#   'temp_max': 65.3,
#   'pressure': 1022,
#   'humidity': 53},
#  'visibility': 10000,
#  'wind': {'speed': 8.05, 'deg': 300},
#  'clouds': {'all': 75},
#  'dt': 1652739062,
#  'sys': {'type': 2,
#   'id': 2013569,
#   'country': 'US',
#   'sunrise': 1652704731,
#   'sunset': 1652758530},
#  'timezone': -25200,
#  'id': 5746545,
#  'name': 'Portland',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | riviere-au-renard
# Processing Record 2 of Set 1 | vostok
# Processing Record 3 of Set 1 | zhangye
# Processing Record 4 of Set 1 | san javier
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | turayf
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | dimona
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | lagoa
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | puerto escondido
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | tombouctou
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | taoudenni
# Processing Record 21 of Set 1 | ilhabela
# Processing Record 22 of Set 1 | druzhba
# Processing Record 23 of Set 1 | craig
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | prince rupert
# Processing Record 26 of Set 1 | pisco
# Processing Record 27 of Set 1 | frederick
# Processing Record 28 of Set 1 | smithers
# Processing Record 29 of Set 1 | krasnyy chikoy
# Processing Record 30 of Set 1 | geraldton
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | esperance
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | khorixas
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | gizo
# Processing Record 44 of Set 1 | sungaipenuh
# Processing Record 45 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | viedma
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | beringovskiy
# Processing Record 1 of Set 2 | akureyri
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | axim
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | tankhoy
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | laguna
# Processing Record 10 of Set 2 | florenville
# Processing Record 11 of Set 2 | conakry
# Processing Record 12 of Set 2 | lavrentiya
# Processing Record 13 of Set 2 | abu dhabi
# Processing Record 14 of Set 2 | fukue
# Processing Record 15 of Set 2 | asyut
# Processing Record 16 of Set 2 | bay city
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | yumen
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | san cristobal
# Processing Record 22 of Set 2 | siocon
# Processing Record 23 of Set 2 | jinxi
# Processing Record 24 of Set 2 | nara
# Processing Record 25 of Set 2 | bairiki
# Processing Record 26 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | vardo
# Processing Record 31 of Set 2 | oyama
# Processing Record 32 of Set 2 | sinnamary
# Processing Record 33 of Set 2 | spencer
# Processing Record 34 of Set 2 | ilo
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | tezu
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | salym
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | chuy
# Processing Record 43 of Set 2 | pekan
# Processing Record 44 of Set 2 | kendal
# Processing Record 45 of Set 2 | bandarbeyla
# Processing Record 46 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 2 | eyl
# Processing Record 48 of Set 2 | tres arroyos
# Processing Record 49 of Set 2 | ambulu
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | anloga
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | fortuna
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | visby
# Processing Record 6 of Set 3 | san patricio
# Processing Record 7 of Set 3 | naica
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | villamartin
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | hohhot
# Processing Record 12 of Set 3 | poso
# Processing Record 13 of Set 3 | lompoc
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | moron
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | poum
# Processing Record 18 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | iquique
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | lingao
# Processing Record 24 of Set 3 | mount isa
# Processing Record 25 of Set 3 | filingue
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | tarbagatay
# Processing Record 28 of Set 3 | hobyo
# Processing Record 29 of Set 3 | seinajoki
# Processing Record 30 of Set 3 | pinega
# Processing Record 31 of Set 3 | ucluelet
# Processing Record 32 of Set 3 | alice springs
# Processing Record 33 of Set 3 | thaton
# Processing Record 34 of Set 3 | narsaq
# Processing Record 35 of Set 3 | guisa
# Processing Record 36 of Set 3 | nantucket
# Processing Record 37 of Set 3 | avera
# Processing Record 38 of Set 3 | oistins
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | narasapur
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | suwa
# Processing Record 44 of Set 3 | marsa matruh
# Processing Record 45 of Set 3 | le port
# Processing Record 46 of Set 3 | roald
# Processing Record 47 of Set 3 | pyu
# Processing Record 48 of Set 3 | bandar-e lengeh
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | saint-augustin
# Processing Record 1 of Set 4 | hamilton
# Processing Record 2 of Set 4 | bilibino
# Processing Record 3 of Set 4 | ipua
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | alampur
# Processing Record 6 of Set 4 | okhotsk
# Processing Record 7 of Set 4 | nishihara
# Processing Record 8 of Set 4 | raudeberg
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | karratha
# Processing Record 11 of Set 4 | pueblo bello
# Processing Record 12 of Set 4 | bolshaya vishera
# City not found. Skipping...
# Processing Record 13 of Set 4 | havoysund
# Processing Record 14 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 4 | castiglione delle stiviere
# Processing Record 16 of Set 4 | riyadh
# Processing Record 17 of Set 4 | cam ranh
# Processing Record 18 of Set 4 | portland
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | mitu
# Processing Record 22 of Set 4 | bontang
# Processing Record 23 of Set 4 | ippy
# Processing Record 24 of Set 4 | makhachkala
# Processing Record 25 of Set 4 | srednekolymsk
# Processing Record 26 of Set 4 | parana
# Processing Record 27 of Set 4 | chokurdakh
# Processing Record 28 of Set 4 | fengkou
# Processing Record 29 of Set 4 | alghero
# Processing Record 30 of Set 4 | rocha
# Processing Record 31 of Set 4 | saint anthony
# Processing Record 32 of Set 4 | byron bay
# Processing Record 33 of Set 4 | salinas
# Processing Record 34 of Set 4 | puerto ayora
# Processing Record 35 of Set 4 | praia
# Processing Record 36 of Set 4 | metro
# Processing Record 37 of Set 4 | ayan
# Processing Record 38 of Set 4 | goure
# Processing Record 39 of Set 4 | dakar
# Processing Record 40 of Set 4 | rio grande
# Processing Record 41 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 4 | jiamusi
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | marawi
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | santa marta de tormes
# Processing Record 48 of Set 4 | asau
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | balkanabat
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | srikakulam
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | dingle
# Processing Record 5 of Set 5 | am timan
# Processing Record 6 of Set 5 | kismayo
# Processing Record 7 of Set 5 | augusto correa
# Processing Record 8 of Set 5 | atambua
# Processing Record 9 of Set 5 | brandon
# Processing Record 10 of Set 5 | aklavik
# Processing Record 11 of Set 5 | quartucciu
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | kidal
# Processing Record 14 of Set 5 | yulara
# Processing Record 15 of Set 5 | dhidhdhoo
# Processing Record 16 of Set 5 | kodar
# Processing Record 17 of Set 5 | saint-paul
# Processing Record 18 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 5 | morbach
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | loreto
# Processing Record 23 of Set 5 | henties bay
# Processing Record 24 of Set 5 | abu kamal
# Processing Record 25 of Set 5 | pangai
# Processing Record 26 of Set 5 | mount gambier
# Processing Record 27 of Set 5 | bend
# Processing Record 28 of Set 5 | lypova dolyna
# Processing Record 29 of Set 5 | santa rosa
# Processing Record 30 of Set 5 | ashland
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | zakharo
# City not found. Skipping...
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | andenes
# Processing Record 35 of Set 5 | celestun
# Processing Record 36 of Set 5 | berdyaush
# Processing Record 37 of Set 5 | port macquarie
# Processing Record 38 of Set 5 | ostrow mazowiecka
# Processing Record 39 of Set 5 | koslan
# Processing Record 40 of Set 5 | claudio
# Processing Record 41 of Set 5 | prata
# Processing Record 42 of Set 5 | jonuta
# Processing Record 43 of Set 5 | cabo san lucas
# Processing Record 44 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 5 | beloha
# Processing Record 47 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 5 | benguela
# Processing Record 49 of Set 5 | sola
# Processing Record 50 of Set 5 | kloulklubed
# Processing Record 1 of Set 6 | kharan
# Processing Record 2 of Set 6 | manakara
# Processing Record 3 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 6 | waddan
# Processing Record 5 of Set 6 | katobu
# Processing Record 6 of Set 6 | thinadhoo
# Processing Record 7 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 8 of Set 6 | san pedro
# Processing Record 9 of Set 6 | farafangana
# Processing Record 10 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 6 | santa isabel
# Processing Record 12 of Set 6 | mapimi
# Processing Record 13 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 6 | bekes
# Processing Record 15 of Set 6 | dalhousie
# Processing Record 16 of Set 6 | hit
# Processing Record 17 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 19 of Set 6 | anju
# Processing Record 20 of Set 6 | souillac
# Processing Record 21 of Set 6 | aktas
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 6 | tual
# Processing Record 25 of Set 6 | khowst
# Processing Record 26 of Set 6 | bud
# Processing Record 27 of Set 6 | itarema
# Processing Record 28 of Set 6 | udachnyy
# Processing Record 29 of Set 6 | westport
# Processing Record 30 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 6 | lyuban
# Processing Record 32 of Set 6 | port augusta
# Processing Record 33 of Set 6 | kruisfontein
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | tiarei
# Processing Record 36 of Set 6 | alofi
# Processing Record 37 of Set 6 | victoria
# Processing Record 38 of Set 6 | eirunepe
# Processing Record 39 of Set 6 | husavik
# Processing Record 40 of Set 6 | sao joao da barra
# Processing Record 41 of Set 6 | saint george
# Processing Record 42 of Set 6 | beisfjord
# Processing Record 43 of Set 6 | acarau
# Processing Record 44 of Set 6 | visnes
# Processing Record 45 of Set 6 | korla
# Processing Record 46 of Set 6 | mehamn
# Processing Record 47 of Set 6 | lumeje
# Processing Record 48 of Set 6 | pimenta bueno
# Processing Record 49 of Set 6 | leningradskiy
# Processing Record 50 of Set 6 | usinsk
# Processing Record 1 of Set 7 | sheksna
# Processing Record 2 of Set 7 | iqaluit
# Processing Record 3 of Set 7 | susanville
# Processing Record 4 of Set 7 | caravelas
# Processing Record 5 of Set 7 | ancud
# Processing Record 6 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 7 | kahului
# Processing Record 8 of Set 7 | odweyne
# Processing Record 9 of Set 7 | camopi
# Processing Record 10 of Set 7 | sao felix do xingu
# Processing Record 11 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 12 of Set 7 | meulaboh
# Processing Record 13 of Set 7 | nombre de dios
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 7 | mazatlan
# Processing Record 17 of Set 7 | nong kung si
# Processing Record 18 of Set 7 | gombong
# Processing Record 19 of Set 7 | woodward
# Processing Record 20 of Set 7 | balkhash
# Processing Record 21 of Set 7 | cesis
# Processing Record 22 of Set 7 | chumikan
# Processing Record 23 of Set 7 | kununurra
# Processing Record 24 of Set 7 | dwarka
# Processing Record 25 of Set 7 | domoni
# Processing Record 26 of Set 7 | harper
# Processing Record 27 of Set 7 | liberal
# Processing Record 28 of Set 7 | arona
# Processing Record 29 of Set 7 | bouake
# Processing Record 30 of Set 7 | polunochnoye
# Processing Record 31 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 7 | ust-nera
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | port blair
# Processing Record 35 of Set 7 | nanortalik
# Processing Record 36 of Set 7 | mwinilunga
# Processing Record 37 of Set 7 | padang
# Processing Record 38 of Set 7 | severo-kurilsk
# Processing Record 39 of Set 7 | ust-uda
# Processing Record 40 of Set 7 | matola
# Processing Record 41 of Set 7 | ostrovnoy
# Processing Record 42 of Set 7 | mielec
# Processing Record 43 of Set 7 | palaikastron
# Processing Record 44 of Set 7 | matamoros
# Processing Record 45 of Set 7 | san blas
# Processing Record 46 of Set 7 | amravati
# Processing Record 47 of Set 7 | diapaga
# Processing Record 48 of Set 7 | cocobeach
# Processing Record 49 of Set 7 | sapao
# City not found. Skipping...
# Processing Record 50 of Set 7 | clyde river
# Processing Record 1 of Set 8 | jiuquan
# Processing Record 2 of Set 8 | berlevag
# Processing Record 3 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 8 | baracoa
# Processing Record 5 of Set 8 | naryan-mar
# Processing Record 6 of Set 8 | mogadishu
# Processing Record 7 of Set 8 | bad harzburg
# Processing Record 8 of Set 8 | mayumba
# Processing Record 9 of Set 8 | awjilah
# Processing Record 10 of Set 8 | talnakh
# Processing Record 11 of Set 8 | richards bay
# Processing Record 12 of Set 8 | nouadhibou
# Processing Record 13 of Set 8 | nhulunbuy
# Processing Record 14 of Set 8 | oranjemund
# Processing Record 15 of Set 8 | aksarka
# Processing Record 16 of Set 8 | hovd
# Processing Record 17 of Set 8 | graciano sanchez
# Processing Record 18 of Set 8 | florianopolis
# Processing Record 19 of Set 8 | rincon
# Processing Record 20 of Set 8 | roma
# Processing Record 21 of Set 8 | lethem
# Processing Record 22 of Set 8 | dali
# Processing Record 23 of Set 8 | alcudia
# Processing Record 24 of Set 8 | paita
# Processing Record 25 of Set 8 | tomatlan
# Processing Record 26 of Set 8 | khatanga
# Processing Record 27 of Set 8 | luwuk
# Processing Record 28 of Set 8 | narasannapeta
# Processing Record 29 of Set 8 | torbay
# Processing Record 30 of Set 8 | puerto ayacucho
# Processing Record 31 of Set 8 | sento se
# City not found. Skipping...
# Processing Record 32 of Set 8 | college
# Processing Record 33 of Set 8 | sakakah
# Processing Record 34 of Set 8 | puerto madryn
# Processing Record 35 of Set 8 | pangkalanbuun
# Processing Record 36 of Set 8 | mnogovershinnyy
# Processing Record 37 of Set 8 | volot
# Processing Record 38 of Set 8 | racine
# Processing Record 39 of Set 8 | turkan
# Processing Record 40 of Set 8 | hualmay
# Processing Record 41 of Set 8 | muros
# Processing Record 42 of Set 8 | kinkala
# Processing Record 43 of Set 8 | toppenish
# Processing Record 44 of Set 8 | carlyle
# Processing Record 45 of Set 8 | tondano
# Processing Record 46 of Set 8 | makakilo city
# Processing Record 47 of Set 8 | bodden town
# Processing Record 48 of Set 8 | constitucion
# Processing Record 49 of Set 8 | kaeo
# Processing Record 50 of Set 8 | faanui
# Processing Record 1 of Set 9 | bulgan
# Processing Record 2 of Set 9 | itaituba
# Processing Record 3 of Set 9 | borogontsy
# Processing Record 4 of Set 9 | manbij
# Processing Record 5 of Set 9 | ixtapa
# Processing Record 6 of Set 9 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 7 of Set 9 | beruwala
# Processing Record 8 of Set 9 | innisfail
# Processing Record 9 of Set 9 | jacareacanga
# Processing Record 10 of Set 9 | te anau
# Processing Record 11 of Set 9 | la vega
# Processing Record 12 of Set 9 | keita
# Processing Record 13 of Set 9 | bonthe
# Processing Record 14 of Set 9 | half moon bay
# Processing Record 15 of Set 9 | tabuk
# Processing Record 16 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 9 | yuci
# Processing Record 18 of Set 9 | bafata
# Processing Record 19 of Set 9 | bengkulu
# Processing Record 20 of Set 9 | mishan
# Processing Record 21 of Set 9 | nisporeni
# Processing Record 22 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 9 | margate
# Processing Record 24 of Set 9 | lexington
# Processing Record 25 of Set 9 | qasigiannguit
# Processing Record 26 of Set 9 | bulaevo
# Processing Record 27 of Set 9 | desaguadero
# Processing Record 28 of Set 9 | guayaramerin
# Processing Record 29 of Set 9 | bulawayo
# Processing Record 30 of Set 9 | neiafu
# Processing Record 31 of Set 9 | fairbanks
# Processing Record 32 of Set 9 | porto velho
# Processing Record 33 of Set 9 | bilma
# Processing Record 34 of Set 9 | cooma
# Processing Record 35 of Set 9 | grand gaube
# Processing Record 36 of Set 9 | coihaique
# Processing Record 37 of Set 9 | kirakira
# Processing Record 38 of Set 9 | komsomolskiy
# Processing Record 39 of Set 9 | sao filipe
# Processing Record 40 of Set 9 | hami
# Processing Record 41 of Set 9 | berasia
# Processing Record 42 of Set 9 | swindon
# Processing Record 43 of Set 9 | necochea
# Processing Record 44 of Set 9 | vila franca do campo
# Processing Record 45 of Set 9 | lorengau
# Processing Record 46 of Set 9 | makurdi
# Processing Record 47 of Set 9 | trelew
# Processing Record 48 of Set 9 | sao domingos do maranhao
# Processing Record 49 of Set 9 | plettenberg bay
# Processing Record 50 of Set 9 | alamosa
# Processing Record 1 of Set 10 | tornio
# Processing Record 2 of Set 10 | barceloneta
# Processing Record 3 of Set 10 | bousso
# Processing Record 4 of Set 10 | ulaanbaatar
# Processing Record 5 of Set 10 | nicoya
# Processing Record 6 of Set 10 | porto novo
# Processing Record 7 of Set 10 | negresti
# Processing Record 8 of Set 10 | krasnovishersk
# Processing Record 9 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 10 of Set 10 | milkovo
# Processing Record 11 of Set 10 | emporia
# Processing Record 12 of Set 10 | duobao
# Processing Record 13 of Set 10 | altamont
# Processing Record 14 of Set 10 | pittsburg
# Processing Record 15 of Set 10 | port hedland
# Processing Record 16 of Set 10 | bangassou
# Processing Record 17 of Set 10 | sibolga
# Processing Record 18 of Set 10 | touros
# Processing Record 19 of Set 10 | praia da vitoria
# Processing Record 20 of Set 10 | jumla
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | lazaro cardenas
# Processing Record 23 of Set 10 | namie
# Processing Record 24 of Set 10 | soto la marina
# Processing Record 25 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 10 | vysokogornyy
# Processing Record 27 of Set 10 | jiexiu
# Processing Record 28 of Set 10 | lamar
# Processing Record 29 of Set 10 | concordia
# Processing Record 30 of Set 10 | buala
# Processing Record 31 of Set 10 | vestmannaeyjar
# Processing Record 32 of Set 10 | saint-georges
# Processing Record 33 of Set 10 | salina
# Processing Record 34 of Set 10 | canmore
# Processing Record 35 of Set 10 | ilulissat
# Processing Record 36 of Set 10 | esso
# Processing Record 37 of Set 10 | sitka
# Processing Record 38 of Set 10 | presidencia roque saenz pena
# Processing Record 39 of Set 10 | comodoro rivadavia
# Processing Record 40 of Set 10 | isangel
# Processing Record 41 of Set 10 | bonfim
# Processing Record 42 of Set 10 | dunedin
# Processing Record 43 of Set 10 | yiyang
# Processing Record 44 of Set 10 | mahajanga
# Processing Record 45 of Set 10 | waitara
# Processing Record 46 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 10 | lufilufi
# Processing Record 48 of Set 10 | uvat
# Processing Record 49 of Set 10 | lixourion
# Processing Record 50 of Set 10 | salalah
# Processing Record 1 of Set 11 | klaksvik
# Processing Record 2 of Set 11 | opuwo
# Processing Record 3 of Set 11 | aswan
# Processing Record 4 of Set 11 | safranbolu
# Processing Record 5 of Set 11 | gat
# Processing Record 6 of Set 11 | vanimo
# Processing Record 7 of Set 11 | buchanan
# Processing Record 8 of Set 11 | angoram
# Processing Record 9 of Set 11 | inuvik
# Processing Record 10 of Set 11 | coahuayana
# Processing Record 11 of Set 11 | mitsamiouli
# Processing Record 12 of Set 11 | forestville
# Processing Record 13 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 11 | lucea
# Processing Record 15 of Set 11 | tambura
# Processing Record 16 of Set 11 | bulembu
# Processing Record 17 of Set 11 | labuhan
# Processing Record 18 of Set 11 | sulangan
# Processing Record 19 of Set 11 | sabzevar
# Processing Record 20 of Set 11 | mandera
# Processing Record 21 of Set 11 | lata
# Processing Record 22 of Set 11 | burgeo
# Processing Record 23 of Set 11 | nago
# Processing Record 24 of Set 11 | gemena
# Processing Record 25 of Set 11 | xining
# Processing Record 26 of Set 11 | talara
# Processing Record 27 of Set 11 | nalut
# Processing Record 28 of Set 11 | surovatikha
# Processing Record 29 of Set 11 | barcelos
# Processing Record 30 of Set 11 | jeremie
# Processing Record 31 of Set 11 | marshall
# Processing Record 32 of Set 11 | broken hill
# Processing Record 33 of Set 11 | tongliao
# Processing Record 34 of Set 11 | east wenatchee bench
# Processing Record 35 of Set 11 | saravan
# Processing Record 36 of Set 11 | verkhniy landekh
# Processing Record 37 of Set 11 | san rafael
# Processing Record 38 of Set 11 | cayenne
# Processing Record 39 of Set 11 | sandpoint
# Processing Record 40 of Set 11 | xiaoweizhai
# Processing Record 41 of Set 11 | walvis bay
# Processing Record 42 of Set 11 | saldanha
# Processing Record 43 of Set 11 | batemans bay
# Processing Record 44 of Set 11 | ukiah
# Processing Record 45 of Set 11 | ahipara
# Processing Record 46 of Set 11 | kondinskoye
# Processing Record 47 of Set 11 | altamira
# Processing Record 48 of Set 11 | svetlogorsk
# Processing Record 49 of Set 11 | santander
# Processing Record 50 of Set 11 | papetoai
# Processing Record 1 of Set 12 | muscat
# Processing Record 2 of Set 12 | mitchell
# Processing Record 3 of Set 12 | flin flon
# Processing Record 4 of Set 12 | progreso
# Processing Record 5 of Set 12 | kourou
# Processing Record 6 of Set 12 | olafsvik
# Processing Record 7 of Set 12 | homer
# Processing Record 8 of Set 12 | alta
# Processing Record 9 of Set 12 | chongwe
# Processing Record 10 of Set 12 | swiecie
# Processing Record 11 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 12 | tadine
# Processing Record 13 of Set 12 | pokosnoye
# Processing Record 14 of Set 12 | terney
# Processing Record 15 of Set 12 | olinda
# Processing Record 16 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | ponyri
# Processing Record 18 of Set 12 | freeport
# Processing Record 19 of Set 12 | russell
# Processing Record 20 of Set 12 | kargasok
# Processing Record 21 of Set 12 | hongjiang
# Processing Record 22 of Set 12 | el alto
# Processing Record 23 of Set 12 | atagay
# Processing Record 24 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 12 | urubicha
# Processing Record 26 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 27 of Set 12 | isla mujeres
# Processing Record 28 of Set 12 | shirokiy
# Processing Record 29 of Set 12 | martapura
# Processing Record 30 of Set 12 | sambava
# Processing Record 31 of Set 12 | qaqortoq
# Processing Record 32 of Set 12 | port maria
# Processing Record 33 of Set 12 | baykit
# Processing Record 34 of Set 12 | honiara
# Processing Record 35 of Set 12 | katsuura
# Processing Record 36 of Set 12 | altay
# Processing Record 37 of Set 12 | buluang
# Processing Record 38 of Set 12 | jaguariaiva
# Processing Record 39 of Set 12 | aktau
# Processing Record 40 of Set 12 | bahia honda
# Processing Record 41 of Set 12 | moindou
# Processing Record 42 of Set 12 | carauari
# Processing Record 43 of Set 12 | kiama
# Processing Record 44 of Set 12 | umuarama
# Processing Record 45 of Set 12 | phatthalung
# Processing Record 46 of Set 12 | faya
# Processing Record 47 of Set 12 | renqiu
# Processing Record 48 of Set 12 | atherton
# Processing Record 49 of Set 12 | manyana
# Processing Record 50 of Set 12 | manzanillo
# Processing Record 1 of Set 13 | golkoy
# Processing Record 2 of Set 13 | blythe
# Processing Record 3 of Set 13 | leshukonskoye
# Processing Record 4 of Set 13 | lamu
# Processing Record 5 of Set 13 | salta
# Processing Record 6 of Set 13 | mabaruma
# Processing Record 7 of Set 13 | miandrivazo
# Processing Record 8 of Set 13 | jalu
# Processing Record 9 of Set 13 | gravdal
# Processing Record 10 of Set 13 | santa fe
# Processing Record 11 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 13 | agutaya
# Processing Record 13 of Set 13 | taman
# Processing Record 14 of Set 13 | paso de patria
# Processing Record 15 of Set 13 | fort nelson
# Processing Record 16 of Set 13 | verkhoyansk
# Processing Record 17 of Set 13 | gao
# Processing Record 18 of Set 13 | tyrma
# Processing Record 19 of Set 13 | aykhal
# Processing Record 20 of Set 13 | minab
# Processing Record 21 of Set 13 | lucatan
# City not found. Skipping...
# Processing Record 22 of Set 13 | tifton
# Processing Record 23 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 24 of Set 13 | hasaki
# Processing Record 25 of Set 13 | bay roberts
# Processing Record 26 of Set 13 | ibatiba
# Processing Record 27 of Set 13 | baijiantan
# Processing Record 28 of Set 13 | bogorodskoye
# Processing Record 29 of Set 13 | amancio
# City not found. Skipping...
# Processing Record 30 of Set 13 | namibe
# Processing Record 31 of Set 13 | willowmore
# Processing Record 32 of Set 13 | pacific grove
# Processing Record 33 of Set 13 | sovetskiy
# Processing Record 34 of Set 13 | bonavista
# Processing Record 35 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 13 | yining
# Processing Record 37 of Set 13 | bom jesus
# Processing Record 38 of Set 13 | kachiry
# Processing Record 39 of Set 13 | acari
# Processing Record 40 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 13 | northam
# Processing Record 42 of Set 13 | aasiaat
# Processing Record 43 of Set 13 | bosilovo
# Processing Record 44 of Set 13 | constantine
# Processing Record 45 of Set 13 | palauig
# Processing Record 46 of Set 13 | okato
# Processing Record 47 of Set 13 | la asuncion
# Processing Record 48 of Set 13 | pitimbu
# Processing Record 49 of Set 13 | sohag
# Processing Record 50 of Set 13 | turinsk
# Processing Record 1 of Set 14 | ternate
# Processing Record 2 of Set 14 | oxapampa
# Processing Record 3 of Set 14 | marzuq
# Processing Record 4 of Set 14 | silos
# Processing Record 5 of Set 14 | wahiawa
# Processing Record 6 of Set 14 | skibbereen
# Processing Record 7 of Set 14 | xinpu
# Processing Record 8 of Set 14 | huarmey
# Processing Record 9 of Set 14 | nizwa
# Processing Record 10 of Set 14 | bowmore
# Processing Record 11 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 14 | inongo
# Processing Record 13 of Set 14 | sorland
# Processing Record 14 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 14 | trofors
# Processing Record 16 of Set 14 | badarpur
# Processing Record 17 of Set 14 | riosucio
# Processing Record 18 of Set 14 | johnstown
# Processing Record 19 of Set 14 | oriximina
# Processing Record 20 of Set 14 | turukhansk
# Processing Record 21 of Set 14 | igrim
# Processing Record 22 of Set 14 | macusani
# Processing Record 23 of Set 14 | havelock
# Processing Record 24 of Set 14 | makushino
# Processing Record 25 of Set 14 | troitsko-pechorsk
# Processing Record 26 of Set 14 | manati
# Processing Record 27 of Set 14 | ust-kan
# Processing Record 28 of Set 14 | sabang
# Processing Record 29 of Set 14 | muzquiz
# City not found. Skipping...
# Processing Record 30 of Set 14 | mopti
# Processing Record 31 of Set 14 | moquegua
# Processing Record 32 of Set 14 | najran
# Processing Record 33 of Set 14 | mason city
# Processing Record 34 of Set 14 | marsh harbour
# Processing Record 35 of Set 14 | vallenar
# Processing Record 36 of Set 14 | kaura namoda
# Processing Record 37 of Set 14 | zapolyarnyy
# Processing Record 38 of Set 14 | izumo
# Processing Record 39 of Set 14 | george town
# Processing Record 40 of Set 14 | iroquois falls
# Processing Record 41 of Set 14 | darque
# Processing Record 42 of Set 14 | singkawang
# Processing Record 43 of Set 14 | kajaani
# Processing Record 44 of Set 14 | jambol
# City not found. Skipping...
# Processing Record 45 of Set 14 | tanjong tokong
# City not found. Skipping...
# Processing Record 46 of Set 14 | notse
# Processing Record 47 of Set 14 | hirara
# Processing Record 48 of Set 14 | quatre cocos
# Processing Record 49 of Set 14 | santa vitoria do palmar
# Processing Record 50 of Set 14 | kasongo-lunda
# Processing Record 1 of Set 15 | muisne
# Processing Record 2 of Set 15 | guerrero negro
# Processing Record 3 of Set 15 | luderitz
# Processing Record 4 of Set 15 | jingdezhen
# Processing Record 5 of Set 15 | ulladulla
# Processing Record 6 of Set 15 | tieli
# Processing Record 7 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 15 | bad durrenberg
# Processing Record 9 of Set 15 | abha
# Processing Record 10 of Set 15 | boyolangu
# Processing Record 11 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 12 of Set 15 | lishui
# Processing Record 13 of Set 15 | abalak
# Processing Record 14 of Set 15 | bartica
# Processing Record 15 of Set 15 | boende
# Processing Record 16 of Set 15 | manacor
# Processing Record 17 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 18 of Set 15 | cherniyiv
# Processing Record 19 of Set 15 | timra
# Processing Record 20 of Set 15 | phulabani
# Processing Record 21 of Set 15 | ulcinj
# Processing Record 22 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 15 | lichuan
# Processing Record 24 of Set 15 | henderson
# Processing Record 25 of Set 15 | zhigansk
# Processing Record 26 of Set 15 | chimoio
# Processing Record 27 of Set 15 | samarai
# Processing Record 28 of Set 15 | strelka
# Processing Record 29 of Set 15 | noumea
# Processing Record 30 of Set 15 | sarkand
# Processing Record 31 of Set 15 | oktyabrskiy
# Processing Record 32 of Set 15 | mocuba
# Processing Record 33 of Set 15 | anadyr
# Processing Record 34 of Set 15 | sao miguel do araguaia
# Processing Record 35 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 15 | nsukka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Riviere-Au-Renard      CA  48.9957  -64.3971     50.29        96
# 1             Vostok      RU  46.4856  135.8833     46.76        64
# 2            Zhangye      CN  38.9342  100.4517     53.31        14
# 3         San Javier      ES  37.8063   -0.8374     71.64        79
# 4              Kapaa      US  22.0752 -159.3190     82.38        80
# 5              Bluff      NZ -46.6000  168.3333     52.81        89
# 6            Ushuaia      AR -54.8000  -68.3000     42.46        87
# 7             Turayf      SA  31.6725   38.6637     68.25        49
# 8       Longyearbyen      SJ  78.2186   15.6401     30.04        86
# 9             Dimona      IL  31.0667   35.0333     64.04        60
#
#    Cloudiness  Wind Speed                 Date      Current Description
# 0         100        3.58  2022-05-16 22:20:44          overcast clouds
# 1          33        2.64  2022-05-16 22:20:45         scattered clouds
# 2         100        5.64  2022-05-16 22:20:45          overcast clouds
# 3          21        3.44  2022-05-16 22:20:46               few clouds
# 4          40        9.22  2022-05-16 22:20:46         scattered clouds
# 5         100        7.76  2022-05-16 22:20:43               light rain
# 6          75       13.80  2022-05-16 22:15:54  light intensity drizzle
# 7           0        6.91  2022-05-16 22:20:47                clear sky
# 8          75        4.61  2022-05-16 22:20:48            broken clouds
# 9         100        8.46  2022-05-16 22:20:48          overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Riviere-Au-Renard      CA  48.9957  -64.3971     50.29        96
# 1                    Vostok      RU  46.4856  135.8833     46.76        64
# 2                   Zhangye      CN  38.9342  100.4517     53.31        14
# 3                San Javier      ES  37.8063   -0.8374     71.64        79
# 4                     Kapaa      US  22.0752 -159.3190     82.38        80
# ..                      ...     ...      ...       ...       ...       ...
# 671             Oktyabrskiy      RU  54.4815   53.4710     45.03        91
# 672                  Mocuba      MZ -16.8392   36.9856     65.50        97
# 673                  Anadyr      RU  64.7500  177.4833     46.90        57
# 674  Sao Miguel Do Araguaia      BR -13.2750  -50.1628     81.09        57
# 675                  Nsukka      NG   6.8561    7.3927     77.13        93
#
#      Cloudiness  Wind Speed Current Description
# 0           100        3.58     overcast clouds
# 1            33        2.64    scattered clouds
# 2           100        5.64     overcast clouds
# 3            21        3.44          few clouds
# 4            40        9.22    scattered clouds
# ..          ...         ...                 ...
# 671          84        5.70       broken clouds
# 672          63        3.09          light rain
# 673           0        4.47           clear sky
# 674          87        5.48     overcast clouds
# 675          93        4.12     overcast clouds
#
# [676 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
